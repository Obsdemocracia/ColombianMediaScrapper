# %%
import pandas as pd
from bs4 import BeautifulSoup 
import requests
import numpy as np

# %%
df= pd.read_csv("paro-and-vacunas-all-story-urls-20210518165532.csv")

# %%
df.columns
# Out:
# Index(['stories_id', 'publish_date', 'title', 'url', 'language',
#        'ap_syndicated', 'themes', 'media_id', 'media_name', 'media_url'],
#       dtype='object')

# %%
counter={}
for i in list(df["media_url"]):
    if i in counter.keys():
        counter[i]+=1
    else:
        counter[i]=1

# %%
df
# Out:
#      stories_id         publish_date  \
# 0    1913175185  2021-04-26 11:13:45
# 1    1913347595  2021-04-26 13:41:53
# 2    1913500823  2021-04-26 16:49:00
# 3    1913522131  2021-04-26 18:06:48
# 4    1913645597  2021-04-26 22:46:18
# ..          ...                  ...
# 564  1934232927  2021-05-17 20:02:58
# 565  1934256840  2021-05-17 15:57:54
# 566  1934302648  2021-05-17 22:56:11
# 567  1934729602  2021-05-17 23:27:37
# 568  1934989809  2021-05-17 20:00:00
#
#                                                  title  \
# 0    Toque de queda en Cundinamarca irá hasta el 2 ...
# 1    Invima no ha recibido ninguna solicitud para u...
# 2    ‘El Presidente sí sabía del IVA para los servi...
# 3    Toque de queda Cundinamarca comenzará a partir...
# 4    ‘Sin subsidio de nómina se quebrará otro 15 % ...
# ..                                                 ...
# 564  Ocupación de camas UCI del área metropolitana ...
# 565  Duque dice cuánto pagaban a migrantes por part...
# 566  Colombia tiene un gobierno a la defensiva que ...
# 567         Acuerdos sí, pero sin vías de hecho: Duque
# 568      ‘Nos vamos a hundir todos si siguen bloqueos’
#
#                                                    url language  \
# 0    http://www.eltiempo.com/bogota/toque-de-queda-...       es
# 1    http://awseb-awseb-6kvd4gz0d20w-1997714897.us-...       es
# 2    https://www.eltiempo.com/politica/gobierno/pre...       es
# 3    https://www.infobae.com/america/colombia/2021/...       es
# 4    https://www.eltiempo.com/bogota/bogota-alcalde...       es
# ..                                                 ...      ...
# 564  https://www.infobae.com/america/colombia/2021/...       es
# 565  https://www.pulzo.com/nacion/duque-dice-que-mi...       es
# 566  https://diariolalibertad.com/sitio/2021/05/17/...       es
# 567  http://periodicodebate.com/index.php/nacion/po...       es
# 568  https://www.portafolio.co/negocios/empresas/no...       es
#
#      ap_syndicated  themes  media_id  \
# 0            False     NaN     38871
# 1            False     NaN     74622
# 2            False     NaN     38871
# 3            False     NaN    695713
# 4            False     NaN     38871
# ..             ...     ...       ...
# 564          False     NaN    695713
# 565          False     NaN    120254
# 566          False     NaN   1330749
# 567          False     NaN    324728
# 568          False     NaN    297900
#
#                                           media_name  \
# 0                                          El Tiempo
# 1                                       rcnradio.com
# 2                                          El Tiempo
# 3                                      Revista Gente
# 4                                          El Tiempo
# ..                                               ...
# 564                                    Revista Gente
# 565                                            Pulzo
# 566  Diario La Libertad - Con La Fuerza De La Verdad
# 567                              periodicodebate.com
# 568                                    portafolio.co
#
#                               media_url
# 0               http://www.eltiempo.com
# 1       http://www.rcnradio.com/#spider
# 2               http://www.eltiempo.com
# 3        https://www.infobae.com/gente/
# 4               http://www.eltiempo.com
# ..                                  ...
# 564      https://www.infobae.com/gente/
# 565                   http://pulzo.com/
# 566  http://diariolalibertad.com/sitio/
# 567         http://periodicodebate.com/
# 568               http://portafolio.co/
#
# [569 rows x 10 columns]

# %%
counter={k: v for k, v in sorted(counter.items(), reverse=True, key=lambda item: item[1])}
counter
# Out:
# {'http://www.eltiempo.com': 107,
#  'https://www.infobae.com/gente/': 107,
#  'http://www.rcnradio.com/#spider': 26,
#  'http://periodicodebate.com/': 22,
#  'http://elnuevosiglo.com.co/': 18,
#  'http://www.elpais.com.co/elpais/': 17,
#  'http://elpais.com.co/': 17,
#  'http://wradio.com.co/': 16,
#  'http://diariolalibertad.com/sitio/': 14,
#  'http://www.hoydiariodelmagdalena.com.co/': 10,
#  'http://elpaisvallenato.com/': 9,
#  'http://lanacion.com.co/': 9,
#  'http://caracol.com.co/': 7,
#  'http://lafm.com.co/': 7,
#  'http://pulzo.com/': 7,
#  'http://lapatilla.com/': 6,
#  'http://cauca.extra.com.co/': 5,
#  'http://llano.extra.com.co/': 5,
#  'http://casanare.extra.com.co/': 5,
#  'http://bucaramanga.extra.com.co/': 5,
#  'http://cali.extra.com.co/': 5,
#  'http://chiquinquira.extra.com.co/': 5,
#  'http://pasto.extra.com.co/': 5,
#  'http://boyaca.extra.com.co/': 5,
#  'http://diariodelsur.com.co/': 5,
#  'http://lapatria.com/': 5,
#  'http://portafolio.co/': 5,
#  'http://www.occidente.co/': 4,
#  'http://larepublica.co/': 4,
#  'http://barrancabermeja.extra.com.co/': 4,
#  'http://ibague.extra.com.co/': 4,
#  'http://cucuta.extra.com.co/': 4,
#  'http://ladorada.extra.com.co/': 4,
#  'http://girardot.extra.com.co/': 4,
#  'http://hsbnoticias.com/': 4,
#  'http://caqueta.extra.com.co/': 4,
#  'https://elexpediente.co/': 4,
#  'http://confidencialcolombia.com/': 4,
#  'http://www.diariodelnorte.net/': 3,
#  'https://45segundos.com/': 3,
#  'http://diariodelcauca.com.co/': 3,
#  'http://palmira.extra.com.co/': 3,
#  'http://extra.com.co/': 3,
#  'https://www.losirreverentes.com/category/noticias/': 3,
#  'https://www.minuto30.com/medellin/': 3,
#  'http://www.eldiario.com.co/inicio': 3,
#  'http://eldiario.com.co/': 3,
#  'http://rionoticias.co/': 3,
#  'http://semanariovoz.com/': 3,
#  'http://elparchedelcapuchino.com/': 3,
#  'https://dontamalio.com': 2,
#  'http://opinioncaribe.com/': 2,
#  'http://canaltropical.co/': 2,
#  'http://putumayo.extra.com.co/': 2,
#  'http://huila.extra.com.co/': 2,
#  'http://elheraldo.co/': 2,
#  'http://laotracara.co/': 2,
#  'http://diariodelhuila.com/': 2,
#  'https://www.prensarural.org/spip/': 2,
#  'http://elnuevoliberal.com/': 2,
#  'https://www.alertapaisa.com': 2,
#  'http://lapiragua.co/': 1,
#  'http://seguimiento.co/': 1,
#  'http://noticordoba.com/': 1,
#  'http://lasillavacia.com/': 1,
#  'http://latarde.com/': 1,
#  'http://revistametro.co/': 1,
#  'http://elpilon.com.co/': 1,
#  'http://www.eltabloide.com.co/': 1,
#  'https://www.villavicenciodiaadia.com/': 1,
#  'http://quintopoder.com.co/': 1,
#  'http://revistadiners.com.co/': 1,
#  'http://laorejaroja.com/': 1,
#  'http://razonpublica.com/': 1}

# %%
url=list(df[df["media_url"]=='http://diariolalibertad.com/sitio/']["url"])
for i in url:
    print(i)
# Out:
# https://diariolalibertad.com/sitio/2021/04/27/el-sistema-de-salud-no-resiste-una-ola-adicional-de-contagios-con-las-marchas-de-este-miercoles/
# https://diariolalibertad.com/sitio/2021/05/01/inconsecuencia-y-mezquindad/
# https://diariolalibertad.com/sitio/2021/05/04/presidente-salga-del-estudio-la-critica-a-ivan-duque-por-the-new-york-times/
# https://diariolalibertad.com/sitio/2021/05/05/colombia-esta-cerca-de-alcanzar-los-dos-millones-de-vacunados-con-segunda-dosis-anticovid/
# https://diariolalibertad.com/sitio/2021/05/07/colombia-alcanzo-un-nuevo-millon-de-vacunas-en-seis-dias/
# https://diariolalibertad.com/sitio/2021/05/08/alcaldes-pidieron-al-comite-del-paro-que-acepte-reunion-con-el-gobierno/
# https://diariolalibertad.com/sitio/2021/05/10/es-un-bloqueo-sistematico-el-que-vive-el-magdalena-desde-el-gobierno-de-duque/
# https://diariolalibertad.com/sitio/2021/05/10/defensoria-continua-gestionando-acuerdo-para-el-suministro-de-gasolina-en-risaralda-quindio-y-cartago/
# https://diariolalibertad.com/sitio/2021/05/10/nos-unimos-al-llamado-de-los-colombianos-a-que-se-levanten-los-bloqueos-duque/
# https://diariolalibertad.com/sitio/2021/05/11/van-42-muertos-en-medio-de-protestas-por-le-paro-nacional-defensoria-del-pueblo/
# https://diariolalibertad.com/sitio/2021/05/13/claudia-blum-renuncio-a-su-cargo-como-ministra-de-relaciones-exteriores/
# https://diariolalibertad.com/sitio/2021/05/15/se-cae-proyecto-de-ley-de-reforma-a-la-salud-del-senador-fabian-castillo-del-clan-uribista-de-los-cotes-carlos-caicedo/
# https://diariolalibertad.com/sitio/2021/05/15/500-mil-empleos-y-pago-estatal-para-su-seguridad-social-propone-uribe-para-los-jovenes/
# https://diariolalibertad.com/sitio/2021/05/17/colombia-tiene-un-gobierno-a-la-defensiva-que-hay-recomponer-gustavo-petro/

# %%
respuesta={}

for i in nuevo_intento[-1:]:
    
    try:
        dk=df[df["media_url"]==i]
        dk=list(dk["url"])[0]
        response = requests.get(dk)
        respuesta.update({i:response})
    except Exception as e:
        print(i)
        respuesta.update({i:e})

# %%
respuesta
# Out:
# {'http://periodicodebate.com/': <Response [406]>}

# %%
fallos={ 'http://periodicodebate.com/': "<Response [406]>", 
        'https://www.minuto30.com/medellin/': "<Response [403]>",
       'http://elnuevoliberal.com/' : "<Response [406]>",
        'http://lasillavacia.com/': "<Response [404]>",
       }

nuevo_intento=['http://periodicodebate.com/']

# %%
response = requests.get(url[0])
sopa= BeautifulSoup(response.text, "html.parser")
response
# Out:
# <Response [403]>

# %%
url= list(df[df["media_url"]=="http://lasillavacia.com/"]["url"])[:10]

url
# Out:
ingresó a la unidad de cuidados intensivos (UCI). "Los médicos nos dijeron que tenía muerte cerebral. Lo más duro para nosotros fue que aunque en ese momento él no estaba muerto, ya nos estaban diciendo que donáramos sus órganos". La última vez que lo vieron fue el domingo 25 de abril. Ese día su corazón y sus otros órganos estaban respondiendo, pero para el 26 se abril la llamada para la familia no fue de alivio. "Le dijeron a mi mamá que mi hermano había muerto. En ese momento se acabaron todas nuestras esperanzas".(Lea: Empresario costeño está a punto de comprar hasta un millón de vacunas) EL TIEMPO intentó comunicarse con el hospital, pero no fue posible lograr contacto.Ni la familia ni los amigos se sintieron bien tratados. "Los médicos indolentes ni siquiera respondían con humanidad cuando uno les preguntaba qué había pasado. Una amiga de la familia lo hizo, y le respondieron: \'¿Qué le puedo decir?, lo mismo que ya saben\' ".Tampoco han recibido ningún avance en la investigación, no se ha capturado a los responsables del crimen, el alcalde de El Rosal no se ha pronunciado. "En conclusión, es como si no hubiera pasado nada". Después de ese asesinato, el municipio de El Rosal, ubicado en el departamento de Cundinamarca, parte de la provincia de Sabana Occidente y a veinte kilómetros de Bogotá, ya no soportó más la seguidilla de problemas de inseguridad.No solo hicieron una velatón por la muerte de Sebastián, sino qu ...
#   'url': 'https://www.eltiempo.com/bogota/asesinato-de-joven-en-el-rosal-cundinamarca-detalles-del-caso-584306'},
#  {'titulo': 'Aunque son pocas las vacunas, en La Estrella ya se hace el procedimiento sin que los usuarios se bajen del carro.',
#   'autor': 'David Andres Calle Atehortua',
#   'fecha': '27 de abril 2021, 02:59 P. M.',
#   'categoría': 'medellín',
#   'contenido': ' En La Estrella, ubicado al sur del valle de Aburrá, ya se están aplicando vacunas contra el covid-19 desde los vehículos y es el primer municipio antioqueño en implementar esta medida.Aunque en la actualidad están llegando pocas vacunas, el procedimiento se está realizando en el parqueadero conjunto al Hospital de La Estrella, a unos 30 metros del servicio de urgencias. (Le puede interesar: Así serán las concentraciones por el Paro Nacional en Medellín) “Nos ha ido muy bien. Los citados salieron, incluso, en el menor tiempo que habíamos planeado y estamos contemplando ya la posibilidad de tener mayor aplicación de dosis en este espacio para que la población no se centre solo en un solo lado, evitando así las aglomeraciones”, explicó Daniel Velásquez, gerente de este hospital.Jesús María Valencia, viajó con su familia y no se tuvo que bajar del carro para que le aplicaran la inyección.“Me parece excelente porque no me encuentro en condiciones óptimas para caminar porque estoy recién operado de una rodilla, sino fuera así, estaría muy incómodo porque tengo que tener mucha quietud”, dijo.(También puede leer: Muere el alcalde de Titiribí, Antioquia, por covid-19) Este municipio ya venía preparando este piloto y ahora ya lo implementa como una alternativa para avanzar en el plan de vacunación contra el covid-19. Por ahora, el servicio en los vehículos es con cita.MEDELLÍN -Esto es lo que se sabe del paro nacional de este 28 de abril\u200b-Piden cerrar vía al Llano para evitar propagación del covid-19-Amenazan a joven que denunció pornografía infantil en chats masivos ',
#   'url': 'https://www.eltiempo.com/colombia/medellin/antioquia-la-estrella-vacuna-contra-covid-19-desde-el-carro-584206'}]

# %%
def eltiempo(url):
    if "opinion" in url:
        response = requests.get(url)
        sopa= BeautifulSoup(response.text, "html.parser")
        
        
        titulo=sopa.find_all(class_="title")[0].get_text()
        autor_categoria=sopa.find_all(class_="who")

        autor=autor_categoria[3].get_text()
        categoria=autor_categoria[0].get_text()
        
        content=sopa.find_all(class_="contenido")
        contenido=""
        for i in content:
            contenido+=" "
            contenido+=(i.get_text())
                
        contenido=contenido.split(u'\n\n\n\n\n\n\n')[0] 
        contenido=contenido.replace(u'\n', u' ')
        contenido=contenido.replace(u'\xa0', u' ')
        fecha=sopa.find_all(class_="publishedAt")
        fecha=fecha[2].get_text()
        
        
    else:
        response = requests.get(url)
        sopa= BeautifulSoup(response.text, "html.parser")
        
        
        
        titulo=sopa.find_all(class_="titulo")[0].get_text()
        
        autor_categoria=sopa.find_all(class_="who")
        
        autor=autor_categoria[3].get_text()
        categoria=autor_categoria[0].get_text()
        
        content=sopa.find_all(class_="contenido")
        contenido=""
        for i in content:
            contenido+=" "
            contenido+=(i.get_text())
        contenido=contenido.split(u'\n\n\n\n\n\n\n')[0] 
        contenido=contenido.replace(u'\n', u' ')
        contenido=contenido.replace(u'\xa0', u' ')
        
        fecha=sopa.find_all(class_="publishedAt")
        fecha=fecha[2].get_text()
        
    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":categoria,
                 "contenido":contenido,"url":url}
    return diccionario

# %%
def rcnradio(url):
    url=url.split(".com")[1]
    url="https://www.rcnradio.com" + url
    
    response = requests.get(url)
    sopa= BeautifulSoup(response.text, "html.parser")
    
    titulo=sopa.find("h1")
    titulo=titulo.get_text()
    
    autor=sopa.find(class_="name-author")
    autor=autor.get_text()
    
    fecha=sopa.find(class_="datetime")
    fecha=fecha.get_text()
    
    categoria=url.split("/")[3]
    
    contenido=sopa.find_all(class_="item4")
    contenido=contenido[0].get_text()
    
    contenido=contenido.replace(u'\n', u' ')
    contenido=contenido.replace(u'\xa0', u' ')
    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":categoria,
             "contenido":contenido,"url":url}
    return diccionario

# %%
def elnuevosiglo(url):
    response = requests.get(url)
    sopa= BeautifulSoup(response.text, "html.parser")
    
    titulo=sopa.find_all(class_="field field--name-title field--type-string field--label-hidden")
    titulo=titulo[0].get_text()
    
    autor_fecha=sopa.find_all(class_="info-line")
    
    fecha=autor_fecha[-1].get_text()
    autor=autor_fecha[0].get_text()
    if autor==fecha: 
        autor=sopa.find_all(class_="username")
        autor=autor[0].get_text()
   

    contenido=sopa.find(class_="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item")
    contenido=contenido.get_text()
    
    contenido=contenido.replace(u'\n', u' ')
    contenido=contenido.replace(u'\xa0', u' ')
    
    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":np.nan,
                 "contenido":contenido,"url":url}
    
    return diccionario

# %%
def elpais(url):
    response = requests.get(url)
    sopa= BeautifulSoup(response.text, "html.parser")    
    
    titulo=sopa.find_all(class_="col-xs-12 article-title")
    titulo=titulo[0].get_text()
    
    fecha=sopa.find_all(class_="published-at")
    fecha=fecha[0].get_text()
    
    autor=sopa.find_all(class_="signature-container")
    autor=autor[0].get_text()
    
    categoria=url.split("/")[3]
    
    content=sopa.find_all(class_="epigraph paragraph")
    contenido=""
    for i in range(len(content)):
        contenido+=" "

        cont=content[i].get_text()

        contenido+=cont
    
    
    contenido=contenido.replace(u'\n', u' ')
    contenido=contenido.replace(u'\xa0', u' ')
    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":categoria,
                 "contenido":contenido,"url":url}
    
    return diccionario

# %%
def wradio(url):
    response = requests.get(url)
    sopa= BeautifulSoup(response.text, "html.parser")
    
    titulo=sopa.find_all("h1")
    titulo=titulo[0].get_text()
    
    autor=sopa.find_all(class_="autor")
    autor=autor[-1].get_text()
    
    fecha=sopa.find_all(class_="actualizado posh")
    fecha=fecha[0].get_text()
    fecha=fecha.split(" -")[0]
    
    
    categoria=sopa.find(class_="titular")
    categoria=categoria.get_text()
    
    contenido=sopa.find_all(class_="cuerpo_noticia estirar")


    contenido=contenido[0].get_text()
    contenido=contenido.split("Reciba desde Google")[0]


    contenido=contenido.replace(u'\n', u' ')
    contenido=contenido.replace(u'\xa0', u' ')

    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":categoria,
                 "contenido":contenido,"url":url}
    
    return diccionario

# %%
def diariomagdalena(url):
    response = requests.get(url)
    sopa= BeautifulSoup(response.text, "html.parser")
    
    titulo=sopa.find(itemprop="headline")
    titulo=titulo.get_text()
    
    autor=np.nan
    
    fecha=sopa.find("time")
    fecha=fecha.get_text()
    try:
        fecha=fecha.split("Última actualización ")[1]
    except:
        fecha=fecha.split("Publicado en ")[1]
    
    
    categoria=sopa.find_all(class_="term-badges")
    categoria=categoria[0].get_text()
    
    
    
    contenido=sopa.find(class_="entry-content clearfix single-post-content")
    contenido=contenido.get_text()
    contenido=contenido.split("\n\nID:")[0]
    contenido=contenido.replace(u'\n', u' ')
    contenido=contenido.replace(u'\xa0', u' ')
    contenido=contenido.split("Síguenos en Telegram")[1]
    
    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":categoria,
             "contenido":contenido,"url":url}

    return diccionario

# %%
def elvallenato(url):
    response = requests.get(url)
    sopa= BeautifulSoup(response.text, "html.parser")
    
    titulo=sopa.find(class_="entry-title post-title")
    titulo=titulo.get_text()
    
    fecha=sopa.find(class_="date updated")
    fecha=fecha.get_text()
    
    categoria=sopa.find(class_="meta-cat")
    categoria=categoria.get_text()
    content=sopa.find_all("p")
    contenido=""
    for i in content[3:]:
        contenido+=i.get_text()
    contenido=contenido.split("Tu dirección de correo")[0]
    
    contenido=contenido.replace(u'\n', u' ')
    contenido=contenido.replace(u'\xa0', u' ')

    
    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":categoria,
         "contenido":contenido,"url":url}

    return diccionario

# %%
def lanacion(url):
    
    
    response = requests.get(url)
    sopa= BeautifulSoup(response.text, "html.parser")
    
    
    titulo=sopa.find(class_="entry-title penci-entry-title penci-title-center")
    titulo=titulo.get_text()
    
    fecha=sopa.find(class_="entry-meta-item penci-posted-on")
    fecha=fecha.get_text()
    fecha=fecha.split(",")
    fecha=fecha[0]+fecha[-1]
    
    autor=sopa.find(class_="author vcard")
    autor=autor.get_text()
    
    categoria=sopa.find_all(itemprop="name")
    categoria=categoria[1].get_text()
    
    content=sopa.find_all(class_="penci-entry-content entry-content")
    content=content[0].find_all("p")
    contenido=""
    for i in content:
        contenido+=i.get_text()

    diccionario={"titulo":titulo,"autor":autor, "fecha":fecha,"categoría":categoria,
         "contenido":contenido,"url":url}

    return diccionario

# %%
titulo=sopa.find(class_="entry-title penci-entry-title penci-title-center")
titulo=titulo.get_text()
imagenes=sopa.find_all("img")
print(titulo)
for i in imagenes:
    a=i.get("alt")
    if titulo[:10] in a:
        print(i)
        print("    ")
# Out:
# Peligroso cruzar líneas
# <img alt="Peligroso cruzar líneas 1 24 mayo, 2021" class="attachment-penci-thumb-960-auto size-penci-thumb-960-auto wp-post-image lazyload" data-sizes="auto" data-src="https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo.jpg?x75474" data-srcset="https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo.jpg 700w, https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo-300x169.jpg 300w, https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo-585x329.jpg 585w" height="394" srcset="..." title="Peligroso cruzar líneas 1 La Nación" width="700"/>
#
# <img alt="Peligroso cruzar líneas 1 24 mayo, 2021" class="attachment-penci-thumb-960-auto size-penci-thumb-960-auto wp-post-image lazy" data-eio="l" data-sizes="(max-width: 700px) 100vw, 700px" data-src="https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo.jpg?x75474" data-srcset="https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo.jpg 700w, https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo-300x169.jpg 300w, https://www.lanacion.com.co/wp-content/uploads/2020/09/Jorge-Luis-Salcedo-Restrepo-585x329.jpg 585w" height="394" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20700%20394'%3E%3C/svg%3E" title="Peligroso cruzar líneas 1 La Nación" width="700"/>

# %%
response = requests.get(url[1])
sopa= BeautifulSoup(response.text, "html.parser")
response
# Out:
# <Response [200]>

# %%
contenido=sopa.find_all("p")
for i in contenido[3:]:
    print(i.get_text())
contenido=contenido.split("Tu dirección de correo")[0]
# Out:
# Es periodista cesarense Sinar Alvarado presenta, para el New York Times, su versión de lo que pasa en el país y de lo que él considera los desaciertos del gobierno de Iván Duque.
# OPINIÓN
# Por: Sinar Alvarado
# Luce lejana la imagen que Iván Duque vendió en campaña: un tipo accesible, vestido de jean y camisa de manga corta, decidido a vivir en el mismo apartamento de siempre después de convertirse en presidente de Colombia hace casi tres años. Ahora es otro: un funcionario distante que habla cada noche por televisión desde el Palacio de Nariño, donde se mantiene recluido por estos días mientras en diversos lugares del país arden las protestas contra su gobierno.
# El momento es crítico: Colombia supera cada día el número de infectados y muertos por la COVID, el desempleo se disparó, la inflación y la pobreza crecen y las ayudas oficiales no logran paliar la crisis. Para corregir el hueco fiscal, empecinado contra las voces que recomiendan postergar el ajuste, Duque impulsa una reforma tributaria que no resuelve la desigualdad histórica de este país.
# Este jueves, después de un paro nacional, el presidente apareció en un programa de radio para decir que mantiene la reforma. No es común verlo ante medios dando explicaciones. Duque se ha guarecido por demasiado tiempo en el set de su programa Prevención y acción. Allí habla de forma rutinaria mientras se queja de la agitación que lo adversa en las calles.
# Hablamos de un jefe de Estado impopular que encontró refugio en la televisión: un ambiente controlado donde habla sin contrapesos. El programa transmite cada vez más propaganda de forma abierta y monopoliza el espectro radioeléctrico con dinero público. Cuando falta solo un año para la próxima elección presidencial, el espacio empieza a convertirse en una ventajosa herramienta de campaña. En cambio, mientras dura esta pugna de hoy, podría ser el espacio donde el presidente discuta con críticos y aliados su controversial reforma.
# Los colombianos no han tenido muchas oportunidades de recibir explicaciones. Durante su gestión, Duque apenas ha hablado ante la prensa, especialmente aquella que lo confronta. En la pandemia, sin embargo, su rostro ubicuo ha invadido los hogares colombianos con un discurso gastado que muy pocos ciudadanos quieren escuchar. El pretendido líder moderno, un tecnócrata conservador, imita a los populistas de izquierda, expertos en multiplicar su imagen con maquinarias de comunicación bien aceitadas.
# En medio de la crisis este gobierno intenta forjar un relato nacional donde las vacunas llegan sin falta, el hambre se ha saciado y el posconflicto avanza sólido. Pero la realidad no se decreta en horario estelar. Esa tarea implica escuchar a muchos, sobre todo a los insatisfechos; y no solo a un reducido coro de aliados.
# Los productores del reality show presidencial deberían incluir invitados diversos que le aporten al anfitrión un saludable vistazo fuera de su estudio insonorizado, a las avenidas y plazas donde palpita el disenso. El ruido de las cacerolas que muchos golpean por las noches es el grito manifiesto de millones de ciudadanos que no quieren ser tratados como espectadores.
